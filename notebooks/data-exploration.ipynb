# %%
# Setup Notebook to load Django code
# From project root, run: jupyter-lab

import os
import sys
from pathlib import Path

django_project_dir = Path('../')
sys.path.insert(0, str(django_project_dir))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "ratom_api.settings.local")

import django
django.setup()

# %%
import pandas as pd
import datetime as dt

from django.db.models import Count
from django.contrib.postgres.search import SearchQuery, SearchVector, SearchRank

from ratom import models as ratom

# %% [markdown]
# # Datasets (.pst, sorted by size)

# %%
! cd /Volumes/Seagate/RATOM/RevisedEDRMv1_Complete && du -hs * | sort -rh | head -15
# Out:
# 3.3G	vkaminski
# 2.4G	sally_beck
# 2.2G	richard_sanders
# 1.7G	sara_shackleton
# 1.6G	matthew_lenhart
# 1.6G	daren_farmer
# 1.5G	kate_symes
# 1.4G	louise_kitchen
# 1.2G	phillip_m_love
# 1.2G	john_lavorato
# 1.2G	gerald_nemec
# 1.2G	darron_c_giron
# 1.1G	richard_shapiro
# 1.1G	mark_taylor
# 1017M	chris_germany

# %% [markdown]
# # Collections

# %%
collections = ratom.Collection.objects.annotate(message_count=Count("message")).order_by("-message_count")
pd.DataFrame(list(collections.values("title", "message_count")))
# Out:
#              title  message_count
# 0       sally_beck          38151
# 1        vkaminski          33503
# 2       kate_symes          13615
# 3  matthew_lenhart           9010
# 4       dana_davis           4269
# 5     susan_bailey           2270

# %% [markdown]
# # Entities (db model)

# %%
collection = ratom.Collection.objects.get(title="kate_symes")
collection
# Out:
# <Collection: kate_symes>

# %%
ratom.Entity.objects.filter(message__collection=collection).count()
# Out:
# 319191

# %%
entities = ratom.Entity.objects.filter(
    message__collection=collection
).values("label").annotate(
    count=Count("value")
).order_by("-count")
pd.DataFrame(list(entities.values("label", "count")))
# Out:
#           label   count
# 0           ORG  137399
# 1        PERSON   60595
# 2      CARDINAL   46517
# 3          DATE   27400
# 4           GPE   13619
# 5          TIME   12639
# 6         MONEY    9954
# 7       ORDINAL    2014
# 8       PRODUCT    1652
# 9           LOC    1600
# 10  WORK_OF_ART    1486
# 11         NORP    1157
# 12          FAC    1077
# 13     QUANTITY     879
# 14      PERCENT     531
# 15        EVENT     499
# 16          LAW     138
# 17     LANGUAGE      35

# %%
person_entities = ratom.Entity.objects.filter(
    message__collection=collection,
    label="ORG"
).values("value").annotate(
    count=Count("value")
).order_by("-count")
pd.DataFrame(list(person_entities.values("value", "count")))[:40]
# Out:
#                                     value  count
# 0                                     PST  13683
# 1                        ZL Technologies,  13615
# 2                   ZL Technologies, Inc.  13615
# 3                                Data Set  13615
# 4                                     NSF  13615
# 5                                     EML  13440
# 6               EDRM Enron Email Data Set  12725
# 7                                   Enron   4151
# 8                                  Prebon    977
# 9                                     EES    919
# 10                                    APB    492
# 11                              BLOOMBERG    395
# 12                                     CP    378
# 13                                  Mid-C    364
# 14                              Dow Jones    356
# 15                                    EOL    306
# 16  PowerMarketers.com Daily Power Report    299
# 17    The PowerMarketers.com Power Report    270
# 18                                  Kerri    237
# 19                                    HOU    228
# 20                                HOU/ECT    213
# 21                            HOU/ECT@ECT    199
# 22                         COB\nBody-Type    198
# 23                                     FW    192
# 24                              Daily EOL    188
# 25        Kerri Thompson/Corp/Enron@ENRON    187
# 26                                     NP    185
# 27                                    BPA    178
# 28                               Pinnacle    166
# 29                                  IMAGE    155
# 30                          Daily EOL/ICE    144
# 31                                   FERC    141
# 32                                     CT    135
# 33              Sierra Pacific Industries    135
# 34                                    EIM    132
# 35                          Pinnacle West    132
# 36                                  ENRON    129
# 37                               Download    124
# 38                             Pacificorp    118
# 39                            Enron Corp.    117

# %%
messages = collection.message_set.filter(
    entities__label="ORG",
    entities__value="Pinnacle West",
)
messages.count()
# Out:
# 132

# %%
message = messages[5]
print(message.msg_body)
# Out:
# Body-Type: plain-text
#
# Thanks so much! I'll pass this along to the traders.
#
# Kate
#
#
# Stephanie Piwetz   03/29/2001 11:52 AM
#
# To: Kate Symes/PDX/ECT@ECT
# cc:
#
# Subject: Re: APS/Pinnacle West
#
# Hello Kate,
# APS and Pinnacle...We ran into a problem checking out for the end of the
# month, because a few deals had Pinnacle in the system, but Bloomberg on the
# bro confirm.  We had to ch them to match the broker confirms, because APS
# showed the deals as APS on there side.  They are trying to segregate
# companies little by little.  We have been told by Rhonda, our contract
# administrator that trading under both names are legally correct, both are
# under WSPP.
#
# DeeDee from Pinnacle said all trades are with Pinnacle unless Bloomberg
# trade; then cp should be APS.  DeeDee said shortly all trades will be under
# Pinnacle, but did not give me a specific date.
#
# Please let the traders know that all trades should be with Pinnacle West, and
# APS that are transacted with Bloomberg.  No, we will not have problems
# recognizing the old name, Rhonda says they will just be assigned over to
# Pinnacle, but we will not have to revise confirms.  Hope this helps!
# Thanks
# Stephanie
#
#
#    Kate Symes                03/29/2001 11:46 AM
#
# To: Stephanie Piwetz/HOU/ECT@ECT
# cc:
# Subject: Re: APS/Pinnacle West
#
# 563906 - changed to Pinnacle West
# 563907 - changed to Pinnacle West
# 562226 - changed to APS
#
# Regarding the last deal, Mike Driscoll talked to his broker at Bloomberg last
# night and asked him to change their confirm to say Pinnacle West. The broker
# said he'd check on it, but that Bloomberg hadn't switched their contract over
# yet and he didn't know if they could check a deal out under the new name. So
# we left it, under the impression that Bloomberg was actually in the wrong. My
# question is - has APS switched over to Pinnacle West entirely, and when or if
# Bloomberg starts recognizing Pinnacle as the counterparty are we going to
# have problems with deals containing the old counterparty name? I'm just
# trying to clarify, so I can let the traders know what to expect. Thanks for
# your help.
#
# Kate
#
#
# Stephanie Piwetz   03/29/2001 07:17 AM
#
# To: Kate Symes/PDX/ECT@ECT
# cc: Evelyn Metoyer/Corp/Enron@Enron, Kimberly Allen/HOU/ECT@ECT
#
# Subject: APS/Pinnacle West
#
# Kate,
#
# I just spoke to DeeDee of Pinnacle West, we verballed deals and she said all
# deals should be under the Pinnacle West name unless for Bloomberg
# transactions.   Please review the following
#
# Mark Fischer
# 563906.01  non brokered > cp name should be Pinnacle West
# 563907.01  non brokered > cp name should be Pinnacle West
#
# 562226.01  Bloomberg, cp name should be Arizona Public Service.  (Evelyn
# inquired about this yesterday)
#
# Thanks for your help!
# Stephanie
#
#
#
#
#
#
#
#
#
# ***********
# EDRM Enron Email Data Set has been produced in EML, PST and NSF format by ZL Technologies, Inc. This Data Set is licensed under a Creative Commons Attribution 3.0 United States License <http://creativecommons.org/licenses/by/3.0/us/> . To provide attribution, please cite to "ZL Technologies, Inc. (http://www.zlti.com)."
# ***********

# %% [markdown]
# # PostgreSQL: Full Text Searching

# %%
collection = ratom.Collection.objects.get(title="kate_symes")
collection
# Out:
# <Collection: kate_symes>

# %%
collection.message_set.count()
# Out:
# 13615

# %%
search_query = SearchQuery('Pinnacle West')
search_vectors = (
    SearchVector('msg_subject', weight='A') +
    SearchVector('msg_body', weight='B') +
    SearchVector('msg_headers', weight='C')
)
search_rank = SearchRank(search_vectors, search_query)

messages = ratom.Message.objects.filter(
    collection=collection,
).exclude(
    directory__contains="/Deleted Items",
).annotate(
    search=search_vectors,
).filter(
    search=search_query,
).annotate(
    rank=search_rank,
).order_by(
    "-rank"
)

# %%
messages.count()
# Out:
# 166

# %%
pd.DataFrame(
    list(
        messages.values(
            "msg_from",
            "sent_date",
            "msg_to",
            "msg_subject",
            "rank",
        )[:20],
    ),
)
# Out:
#               msg_from                 sent_date              msg_to  \
# 0         "Kate Symes" 2001-03-30 00:47:00+00:00  "Stephanie Piwetz"
# 1         "Kate Symes" 2001-03-30 00:47:00+00:00  "Stephanie Piwetz"
# 2         "Kate Symes" 2001-03-30 00:47:00+00:00  "Stephanie Piwetz"
# 3         "Kate Symes" 2001-03-30 00:47:00+00:00  "Stephanie Piwetz"
# 4   "Stephanie Piwetz" 2001-03-30 02:52:00+00:00        "Kate Symes"
# 5   "Stephanie Piwetz" 2001-03-30 02:52:00+00:00        "Kate Symes"
# 6   "Stephanie Piwetz" 2001-03-30 02:52:00+00:00        "Kate Symes"
# 7    "Rhonda L Denton" 2001-01-27 03:21:00+00:00        "Kate Symes"
# 8    "Rhonda L Denton" 2001-01-27 03:21:00+00:00        "Kate Symes"
# 9    "Rhonda L Denton" 2001-01-27 03:21:00+00:00        "Kate Symes"
# 10        "Kate Symes" 2001-03-29 22:46:00+00:00  "Stephanie Piwetz"
# 11        "Kate Symes" 2001-03-29 22:46:00+00:00  "Stephanie Piwetz"
# 11       "Kate Symes" 2001-01-27 00:55:00+00:00  "Portland Shift"
# 12       "Kate Symes" 2001-01-27 00:55:00+00:00  "Portland Shift"
# 13       "Kate Symes" 2001-01-27 00:55:00+00:00  "Portland Shift"
# 14   "Kerri Thompson" 2000-12-11 22:21:00+00:00      "Kate Symes"
# 15   "Kerri Thompson" 2000-12-11 22:21:00+00:00      "Kate Symes"
# 16   "Kerri Thompson" 2000-12-11 22:21:00+00:00      "Kate Symes"
# 17   "Evelyn Metoyer" 2000-12-05 01:07:00+00:00      "Kate Symes"
# 18   "Evelyn Metoyer" 2000-12-05 01:07:00+00:00      "Kate Symes"
# 19   "Evelyn Metoyer" 2000-12-05 01:07:00+00:00      "Kate Symes"
#
#                                msg_subject      rank
# 0                            Pinnacle West  0.995378
# 1                            Pinnacle West  0.995378
# 2                            Pinnacle West  0.995378
# 3     Re: Deal #477087.01 Pinnacle West...  0.991032
# 4     Re: Deal #477087.01 Pinnacle West...  0.991032
# 5     Re: Deal #477087.01 Pinnacle West...  0.991032
# 6     Re: Deal #477087.01 Pinnacle West...  0.991032
# 7     Re: Deal #477087.01 Pinnacle West...  0.991032
# 8     Re: Deal #477087.01 Pinnacle West...  0.991032
# 9     Re: Deal #477087.01 Pinnacle West...  0.991032
# 10  Transmission deals - APS, not Pinnacle  0.654166
# 11  Transmission deals - APS, not Pinnacle  0.654166
# 12  Transmission deals - APS, not Pinnacle  0.654166
# 13  Transmission deals - APS, not Pinnacle  0.654166
# 14                                          0.653502
# 15                                          0.653502
# 16                                          0.653502
# 17                             Deal 471553  0.396413
# 18                             Deal 471553  0.396413
# 19                             Deal 471553  0.396413

# %%
print(messages_without_person[0].msg_body)
# Out:
# Body-Type: plain-text
#
# Please check deal no. 500771 under Pinnacle West.  I thought Arizona Public
# Service kept all transmisson.  Please let me know what you find out.
#
# ***********
# EDRM Enron Email Data Set has been produced in EML, PST and NSF format by ZL Technologies, Inc. This Data Set is licensed under a Creative Commons Attribution 3.0 United States License <http://creativecommons.org/licenses/by/3.0/us/> . To provide attribution, please cite to "ZL Technologies, Inc. (http://www.zlti.com)."
# ***********

# %% [markdown]
# # Using MessageManager

# %%
collection = ratom.Collection.objects.get(title="kate_symes")
collection
# Out:
# <Collection: kate_symes>

# %%
text = 'Pinnacle West'

# %%
messages = ratom.Message.objects.search(
    text,
).filter(
    collection=collection,
)
messages.count()
# Out:
# 166

# %% [markdown]
# # JSONField .data Field

# %%
collection = ratom.Collection.objects.get(title="sally_beck")
collection
# Out:
# <Collection: sally_beck>

# %%
collection.message_set.count()
# Out:
# 38151

# %%
messages = ratom.Message.objects.filter(
    collection=collection,
).filter(
    data__labels__contains="PERSON"
)
messages.count()
# Out:
# 29532
